# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My Drive/Project/
# Out:
# /content/gdrive/My Drive/Project

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Project

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/Project/.git/

# %%
# !git remote add origin https://willywildan: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@github.com/willywildan/ETLwithPandas.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://willywildan:Hayamanakan1@github.com/willywildan/ETLwithPandas.git (fetch)
# origin	https://willywildan:Hayamanakan1@github.com/willywildan/ETLwithPandas.git (push)

# %%
# !git config --global user.email 'willywildankamal@gmail'
# !git config --global user.name 'willywildan'

# %%
# !git add README.md
# !git commit -m 'First commit'
# Out:
# fatal: pathspec 'README.md' did not match any files
# On branch master
# Changes not staged for commit:
# 	modified:   gitColab/gitCommands.ipynb
#
# no changes added to commit

# %%
# !git push origin master
# Out:
# remote: Support for password authentication was removed on August 13, 2021. Please use a personal access token instead.
# remote: Please see https://github.blog/2020-12-15-token-authentication-requirements-for-git-operations/ for more information.
# fatal: Authentication failed for 'https://willywildan:Hayamanakan1@github.com/willywildan/ETLwithPandas.git/'
